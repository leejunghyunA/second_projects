# %% [markdown]
# ## 분류로직 데이터 불러오기

# %%
import pandas as pd
final_cat = pd.read_excel('최종cat순서나열.xlsx', index_col=0)
final_cat.drop(columns=['대분류코드'], inplace=True)

# %%
final_cat.drop(columns=['구매금액_min', '구매금액_max', '구매금액_mean'], inplace=True)

# %%
final_cat
# Out:
#      제휴사 금액 타입 대분류명_y 중분류명             소분류명  UPRICE     QTY    AVG  AVGVS
# 0      B    저가     식품   버섯              건버섯    3017  123931   7926    0.4
# 1      B    저가     식품   버섯            느타리버섯    3017  123931   7926    0.4
# 2      B    저가     식품   버섯             버섯모둠    3017  123931   7926    0.4
# 3      B    저가     식품   버섯           버섯선물세트    3017  123931   7926    0.4
# 4      B    저가     식품   버섯            새송이버섯    3017  123931   7926    0.4
# ...   ..   ...    ...  ...              ...     ...     ...    ...    ...
# 4611   A    중가    멀티샵   기타         PECK G&C   96379     649  96379    1.0
# 4612   A    중가    멀티샵   기타  PECK Restaurant   96379     649  96379    1.0
# 4613   A    중가    멀티샵   기타            멘즈셀렉샵   96379     649  96379    1.0
# 4614   A    중가    멀티샵   기타           스테이셔너리   96379     649  96379    1.0
# 4615   A    중가    멀티샵   기타             팩토리샵   96379     649  96379    1.0
#
# [4616 rows x 9 columns]

# %%
final_cat
# Out:
#      제휴사 금액 타입 대분류명_y 중분류명             소분류명  UPRICE     QTY    AVG  AVGVS  \
# 0      B    저가     식품   버섯              건버섯    3017  123931   7926    0.4
# 1      B    저가     식품   버섯            느타리버섯    3017  123931   7926    0.4
# 2      B    저가     식품   버섯             버섯모둠    3017  123931   7926    0.4
# 3      B    저가     식품   버섯           버섯선물세트    3017  123931   7926    0.4
# 4      B    저가     식품   버섯            새송이버섯    3017  123931   7926    0.4
# ...   ..   ...    ...  ...              ...     ...     ...    ...    ...
# 4611   A    중가    멀티샵   기타         PECK G&C   96379     649  96379    1.0
# 4612   A    중가    멀티샵   기타  PECK Restaurant   96379     649  96379    1.0
# 4613   A    중가    멀티샵   기타            멘즈셀렉샵   96379     649  96379    1.0
# 4614   A    중가    멀티샵   기타           스테이셔너리   96379     649  96379    1.0
# 4615   A    중가    멀티샵   기타             팩토리샵   96379     649  96379    1.0
#
#                ASSO_SCL
# 0                 B_건버섯
# 1               B_느타리버섯
# ...

# %%
final_cat['ASSO_SCL'] = final_cat['제휴사'] + '_' + final_cat['소분류명']

# %% [markdown]
# ## df1 불러오기

# %%
import pandas as pd
df1 = pd.read_csv('C:/cakd7/2차 프로젝트/purchase_유지_연도 및 금액타입 포함(split1).csv', index_col=0)
df1
# Out:
# C:\Users\admin\AppData\Roaming\Python\Python38\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\admin\AppData\Roaming\Python\Python38\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\admin\AppData\Roaming\Python\Python38\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:\n%s" %
#           CUSTNO ASSO  STCODE       RNO   BBCL BCL    MCL     SCL TYPE  \
# 0          17218    B      44   8664000  식품/생활  식품   탄산음료     사이다  일용품
# 1          11303    B      44   8664007  식품/생활  식품   탄산음료     사이다  일용품
# 2          13210    B      48   8919520  식품/생활  식품   탄산음료     사이다  일용품
# 3          13823    B      12   6956422  식품/생활  식품   탄산음료     사이다  일용품
# 4          18970    B      12   6957156  식품/생활  식품   탄산음료     사이다  일용품
# ...

# %%
q1_1 = df1[(df1['PURYEAR'] == 2014) & (df1['QUARTER'].isin([1,2,3]))]
q1_2 = df1[(df1['PURYEAR'] == 2014) & (df1['QUARTER'].isin([2,3,4]))]

q1_3 = df1[((df1['PURYEAR'] == 2014) & (df1['QUARTER'].isin([3, 4])))|
           ((df1['PURYEAR'] == 2015) & (df1['QUARTER'].isin([1])))]
q1_4 = df1[(df1['PURYEAR'] == 2014) & (df1['QUARTER'].isin([4]))|
           ((df1['PURYEAR'] == 2015) & (df1['QUARTER'].isin([1,2])))]
q1_5 = df1[(df1['PURYEAR'] == 2015) & (df1['QUARTER'].isin([1,2,3]))]
q1_6 = df1[(df1['PURYEAR'] == 2015) & (df1['QUARTER'].isin([2,3,4]))]

# %%
df2 = pd.read_csv('C:/cakd7/2차 프로젝트/purchase_유지_연도 및 금액타입 포함(split2).csv', index_col=0)
df2
# Out:
#           CUSTNO ASSO  STCODE      RNO         BBCL   BCL      MCL       SCL  \
# 14265420    7249    C     200  7252615        식품/생활    식품    국내산돈육    국산돼지목심
# 14265421    3733    C     292  9196569        식품/생활    식품    국내산돈육    국산돼지목심
# 14265422    8710    C     277  8617166        식품/생활    식품    국내산돈육    국산돼지목심
# 14265423   16883    C     475  6641782        식품/생활    식품    국내산돈육    국산돼지목심
# 14265424    5625    C      64   976199        식품/생활    식품    국내산돈육    국산돼지목심
# ...          ...  ...     ...      ...          ...   ...      ...       ...
# 28593025     134    B      16  7269975        식품/생활    식품     전통과자  온라인팥빙수재료
# 28593026   18484    B      26  7946814    가구인테리어/잡화    잡화     여성양말     여성발가락
# 28593027    5043    B      21  7777110        식품/생활    식품   즉석구이안주      즉석쥐포
# 28593028    4073    B      18  7579178        식품/생활    식품     마른안주    온라인 안주
# 28593029   11509    B      29  8123279  가전/레저취미/멀티샵  레저취미  시니어건강용품      침실용품
#
# ...

# %%
q2_1 = df2[(df2['PURYEAR'] == 2014) & (df2['QUARTER'].isin([1,2,3]))]
q2_2 = df2[(df2['PURYEAR'] == 2014) & (df2['QUARTER'].isin([2,3,4]))]

q2_3 = df2[((df2['PURYEAR'] == 2014) & (df2['QUARTER'].isin([3, 4])))|
           ((df2['PURYEAR'] == 2015) & (df2['QUARTER'].isin([1])))]
q2_4 = df2[(df2['PURYEAR'] == 2014) & (df2['QUARTER'].isin([4]))|
           ((df2['PURYEAR'] == 2015) & (df2['QUARTER'].isin([1,2])))]
q2_5 = df2[(df2['PURYEAR'] == 2015) & (df2['QUARTER'].isin([1,2,3]))]
q2_6 = df2[(df2['PURYEAR'] == 2015) & (df2['QUARTER'].isin([2,3,4]))]

# %%
q2_6
# Out:
#           CUSTNO ASSO  STCODE       RNO         BBCL   BCL      MCL       SCL  \
# 14265425   11118    C     122   6024246        식품/생활    식품    국내산돈육    국산돼지목심
# 14265426    6473    C     144   6118508        식품/생활    식품    국내산돈육    국산돼지목심
# 14265436    5183    C     183   6857890        식품/생활    식품    국내산돈육    국산돼지목심
# 14265437   13381    C      55    274050        식품/생활    식품    국내산돈육    국산돼지목심
# 14265439    4386    C     182   6826471        식품/생활    식품    국내산돈육    국산돼지목심
# ...          ...  ...     ...       ...          ...   ...      ...       ...
# 28593020   15129    B     135  11096577        식품/생활    식품    커피차음료  온라인커피차음료
# 28593021    4995    B     135  11096579    가구인테리어/잡화    잡화       가방     온라인가방
# 28593022    1801    B     135  11096580        식품/생활    식품     탄산음료  온라인 탄산음료
# 28593027    5043    B      21   7777110        식품/생활    식품   즉석구이안주      즉석쥐포
# 28593029   11509    B      29   8123279  가전/레저취미/멀티샵  레저취미  시니어건강용품      침실용품
#
# ...

# %%
q1_q3 = pd.concat([q1_1, q2_1], axis = 0)
q2_q4 = pd.concat([q1_2, q2_2], axis = 0)
q3_q5 = pd.concat([q1_3, q2_3], axis = 0)
q4_q6 = pd.concat([q1_4, q2_4], axis = 0)
q5_q7 = pd.concat([q1_5, q2_5], axis = 0)
q6_q8 = pd.concat([q1_6, q2_6], axis = 0)
q6_q8
# Out:
#           CUSTNO ASSO  STCODE       RNO         BBCL   BCL      MCL       SCL  \
# 2          13210    B      48   8919520        식품/생활    식품     탄산음료       사이다
# 5          15642    B       9   6817184        식품/생활    식품     탄산음료       사이다
# 6           7240    B      75   9571864        식품/생활    식품     탄산음료       사이다
# 7           4996    B      68   9378229        식품/생활    식품     탄산음료       사이다
# 9           2492    B      44   8767387        식품/생활    식품     탄산음료       사이다
# ...          ...  ...     ...       ...          ...   ...      ...       ...
# 28593020   15129    B     135  11096577        식품/생활    식품    커피차음료  온라인커피차음료
# 28593021    4995    B     135  11096579    가구인테리어/잡화    잡화       가방     온라인가방
# 28593022    1801    B     135  11096580        식품/생활    식품     탄산음료  온라인 탄산음료
# 28593027    5043    B      21   7777110        식품/생활    식품   즉석구이안주      즉석쥐포
# 28593029   11509    B      29   8123279  가전/레저취미/멀티샵  레저취미  시니어건강용품      침실용품
#
# ...

# %%
purchase['ASSO_SCL'] = purchase['ASSO'] + '_' + purchase['SCL']
purchase.head()
# Out:
#    CUSTNO ASSO  STCODE      RNO   BBCL BCL   MCL  SCL TYPE   PURDATE  PURYEAR  \
# 0   17218    B      44  8664000  식품/생활  식품  탄산음료  사이다  일용품  20140222     2014
# 1   11303    B      44  8664007  식품/생활  식품  탄산음료  사이다  일용품  20140222     2014
# 2   13210    B      48  8919520  식품/생활  식품  탄산음료  사이다  일용품  20150921     2015
# 3   13823    B      12  6956422  식품/생활  식품  탄산음료  사이다  일용품  20140813     2014
# 4   18970    B      12  6957156  식품/생활  식품  탄산음료  사이다  일용품  20140831     2014
#
#    QUARTER  PURMONTH  PURHOUR  PURAMT PRICE_TYPE ASSO_SCL
# 0        1         2       20    2420         중가    B_사이다
# 1        1         2       13    2400         중가    B_사이다
# 2        3         9       19    5250         중가    B_사이다
# 3        3         8       18    2250         중가    B_사이다
# 4        3         8       22    4900         중가    B_사이다

# %% [markdown]
# ## df1 상품별 구매건수

# %%
pivot = pd.pivot_table(df1,
                       index='CUSTNO', 
                       columns='ASSO_SCL', 
                       values='RNO', 
                       aggfunc='count')
pivot
# Out:
# ASSO_SCL  B_HMR  B_Local상추  B_Local얼갈이  B_NB 돼지고기  B_NB돼지고기  B_PB 계란  \
# CUSTNO
# 1           NaN        NaN         NaN        NaN       NaN      NaN
# 2           NaN        NaN         NaN        NaN       NaN      NaN
# 3           NaN        NaN         NaN        NaN       NaN      NaN
# 4           NaN        NaN         NaN        NaN       NaN      NaN
# 6           NaN        8.0         NaN        NaN       NaN      4.0
# ...         ...        ...         ...        ...       ...      ...
# 19333       NaN        NaN         NaN        NaN       NaN      NaN
# 19334       2.0        NaN         NaN        4.0       2.0      NaN
# 19335       NaN        NaN         NaN        NaN       NaN      NaN
# 19336       NaN        NaN         NaN        NaN       NaN      NaN
# 19337       NaN        NaN         NaN        NaN       NaN      NaN
#
# ASSO_SCL  B_PB 돼지고기  B_PB 한우  B_PB돼지고기  B_PB바나나  ...  C_콘아이스크림  C_콜라  C_파이  \
# ...

# %% [markdown]
# ### 상품별 단가 가중치 곱해주기

# %%
col_list =list(pivot.columns)

for col in col_list:
    for cat in list(final_cat['ASSO_SCL']):
        if col == cat:
            index = int(final_cat[fin  al_cat['ASSO_SCL']==cat].index[0])
            pivot[col] = pivot[col] * final_cat.loc[index,'AVGVS']
            break
        else:
            pass
            
        
pivot
# Out:
# ASSO_SCL  B_HMR  B_Local상추  B_Local얼갈이  B_NB 돼지고기  B_NB돼지고기  B_PB 계란  \
# CUSTNO
# 1           NaN        NaN         NaN        NaN       NaN      NaN
# 2           NaN        NaN         NaN        NaN       NaN      NaN
# 3           NaN        NaN         NaN        NaN       NaN      NaN
# 4           NaN        NaN         NaN        NaN       NaN      NaN
# 6           NaN        1.6         NaN        NaN       NaN      2.8
# ...         ...        ...         ...        ...       ...      ...
# 19333       NaN        NaN         NaN        NaN       NaN      NaN
# 19334       2.8        NaN         NaN        6.8       3.2      NaN
# 19335       NaN        NaN         NaN        NaN       NaN      NaN
# 19336       NaN        NaN         NaN        NaN       NaN      NaN
# 19337       NaN        NaN         NaN        NaN       NaN      NaN
#
# ASSO_SCL  B_PB 돼지고기  B_PB 한우  B_PB돼지고기  B_PB바나나  ...  C_콘아이스크림  C_콜라  C_파이  \
# ...

# %% [markdown]
# ### 확인해봄

# %%
pivot.isnull().sum().sum()
# Out:
# 10107768

# %%
pivot21 = pivot.copy()
final_cat21 = final_cat.copy()

# %%
pivot21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18537 entries, 1 to 19337
# Columns: 696 entries, B_HMR to C_후추
# dtypes: float64(696)
# memory usage: 98.6 MB

# %%
col_list =list(pivot21.columns)

for col in col_list:
    for cat in list(final_cat21['ASSO_SCL']):
        if col == cat:
            pivot21[col] = '확인'
            
            
            
            break
        else:
            pass
            
        
pivot21
# Out:
# ASSO_SCL B_HMR B_Local상추 B_Local얼갈이 B_NB 돼지고기 B_NB돼지고기 B_PB 계란 B_PB 돼지고기  \
# CUSTNO
# 1           확인        확인         확인        확인       확인      확인        확인
# 2           확인        확인         확인        확인       확인      확인        확인
# 3           확인        확인         확인        확인       확인      확인        확인
# 4           확인        확인         확인        확인       확인      확인        확인
# 6           확인        확인         확인        확인       확인      확인        확인
# ...        ...       ...        ...       ...      ...     ...       ...
# 19333       확인        확인         확인        확인       확인      확인        확인
# 19334       확인        확인         확인        확인       확인      확인        확인
# 19335       확인        확인         확인        확인       확인      확인        확인
# 19336       확인        확인         확인        확인       확인      확인        확인
# 19337       확인        확인         확인        확인       확인      확인        확인
#
# ASSO_SCL B_PB 한우 B_PB돼지고기 B_PB바나나  ... C_콘아이스크림 C_콜라 C_파이 C_파인애플 C_포도 C_푸딩/젤리  \
# ...

# %%
pivot21.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## df2 상품별 구매건수

# %%
df2 = pd.read_csv('purchase2_include_pt.csv', index_col=0)
df2
# Out:
#           CUSTNO ASSO  STCODE      RNO         BBCL   BCL      MCL       SCL  \
# 14127934    7249    C     200  7252615        식품/생활    식품    국내산돈육    국산돼지목심
# 14127935    3733    C     292  9196569        식품/생활    식품    국내산돈육    국산돼지목심
# 14127936    8710    C     277  8617166        식품/생활    식품    국내산돈육    국산돼지목심
# 14127937   16883    C     475  6641782        식품/생활    식품    국내산돈육    국산돼지목심
# 14127938    5625    C      64   976199        식품/생활    식품    국내산돈육    국산돼지목심
# ...          ...  ...     ...      ...          ...   ...      ...       ...
# 28255863     134    B      16  7269975        식품/생활    식품     전통과자  온라인팥빙수재료
# 28255864   18484    B      26  7946814    가구인테리어/잡화    잡화     여성양말     여성발가락
# 28255865    5043    B      21  7777110        식품/생활    식품   즉석구이안주      즉석쥐포
# 28255866    4073    B      18  7579178        식품/생활    식품     마른안주    온라인 안주
# 28255867   11509    B      29  8123279  가전/레저취미/멀티샵  레저취미  시니어건강용품      침실용품
#
# ...

# %%
df2['ASSO_SCL'] = df2['ASSO'] + '_' + df2['SCL']

# %%
pivot2 = pd.pivot_table(df2, index='CUSTNO', columns='ASSO_SCL', values='RNO', aggfunc='count')
pivot2
# Out:
# ASSO_SCL  A_14K  A_4대 B/D  A_5 ON THE GO  A_ACC Bloom (1F)  A_ACC Bloom (3F)  \
# CUSTNO
# 1           NaN       NaN            NaN               NaN               NaN
# 2           NaN       NaN            NaN               NaN               NaN
# 3           NaN       NaN            NaN               NaN               NaN
# 4           NaN       NaN            NaN               NaN               NaN
# 6           NaN       NaN            NaN               NaN               NaN
# ...         ...       ...            ...               ...               ...
# 19333       NaN       NaN            NaN               NaN               NaN
# 19334       NaN       NaN            NaN               NaN               NaN
# 19335       NaN       1.0            NaN               NaN               NaN
# 19336       1.0       NaN            NaN               NaN               NaN
# 19337       NaN       NaN            NaN               NaN               NaN
#
# ...

# %% [markdown]
# ### df2 상품별 단가 가중치 곱해줌

# %%
col_list =list(pivot2.columns)

for col in col_list:
    for cat in list(final_cat['ASSO_SCL']):
        if col == cat:
            index = int(final_cat[final_cat['ASSO_SCL']==cat].index[0])
            pivot2[col] = pivot2[col] * final_cat.loc[index,'AVGVS']
            break
        else:
            pass
            
        
pivot2
# Out:
# ASSO_SCL  A_14K  A_4대 B/D  A_5 ON THE GO  A_ACC Bloom (1F)  A_ACC Bloom (3F)  \
# CUSTNO
# 1           NaN       NaN            NaN               NaN               NaN
# 2           NaN       NaN            NaN               NaN               NaN
# 3           NaN       NaN            NaN               NaN               NaN
# 4           NaN       NaN            NaN               NaN               NaN
# 6           NaN       NaN            NaN               NaN               NaN
# ...         ...       ...            ...               ...               ...
# 19333       NaN       NaN            NaN               NaN               NaN
# 19334       NaN       NaN            NaN               NaN               NaN
# 19335       NaN       1.9            NaN               NaN               NaN
# 19336       1.0       NaN            NaN               NaN               NaN
# 19337       NaN       NaN            NaN               NaN               NaN
#
# ...

# %% [markdown]
# #### 확인해봄

# %%
final_cat.loc[final_cat['ASSO_SCL'] =='B_Local상추', 'AVGVS']
# Out:
# 60    0.2
# Name: AVGVS, dtype: float64

# %% [markdown]
# ### 구매지수 분자 부분 저장함

# %%
pivot.to_csv('purchase_index1.csv')
pivot2.to_csv('purchase_index2.csv')

# %% [markdown]
# ## 분모 구함

# %%
df = pd.concat([df1, df2], axis=0)
df
# Out:
#           CUSTNO ASSO  STCODE      RNO         BBCL   BCL      MCL       SCL  \
# 0          17218    B      44  8664000        식품/생활    식품     탄산음료       사이다
# 1          11303    B      44  8664007        식품/생활    식품     탄산음료       사이다
# 2          13210    B      48  8919520        식품/생활    식품     탄산음료       사이다
# 3          13823    B      12  6956422        식품/생활    식품     탄산음료       사이다
# 4          18970    B      12  6957156        식품/생활    식품     탄산음료       사이다
# ...          ...  ...     ...      ...          ...   ...      ...       ...
# 28255863     134    B      16  7269975        식품/생활    식품     전통과자  온라인팥빙수재료
# 28255864   18484    B      26  7946814    가구인테리어/잡화    잡화     여성양말     여성발가락
# 28255865    5043    B      21  7777110        식품/생활    식품   즉석구이안주      즉석쥐포
# 28255866    4073    B      18  7579178        식품/생활    식품     마른안주    온라인 안주
# 28255867   11509    B      29  8123279  가전/레저취미/멀티샵  레저취미  시니어건강용품      침실용품
#
# ...

# %%
cust_f_sum = pd.pivot_table(df, index='CUSTNO', values='RNO', aggfunc='count')
cust_f_sum
# Out:
#          RNO
# CUSTNO
# 1       1057
# 2       1116
# 3       1191
# 4        930
# 6       1593
# ...      ...
# 19333    824
# 19334   1964
# 19335   1873
# 19336    440
# 19337   1321
#
# [18866 rows x 1 columns]

# %% [markdown]
# ## 구매지수 계산

# %%
col_list =list(pivot2.columns)

for col in col_list:
    for cat in list(final_cat['ASSO_SCL']):
        if col == cat:
            index = int(final_cat[final_cat['ASSO_SCL']==cat].index[0])
            pivot2[col] = pivot2[col] * final_cat.loc[index,'AVGVS']
            break
        else:
            pass
            
        
pivot2

# %%
for i1 in pivot.index:
    for i2 in df.index:
        if i1 == i2:
            bunmo = pivot.loc[i1, 'RNO']
            purchase_index = df.loc[i2, :] / bunmo
