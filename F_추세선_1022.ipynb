# %%
import pandas as pd


df2= pd.read_csv('purchase2_include_pt.csv')
df1 = pd.read_csv('purchase1_include_pt.csv')

# %%
f1 = pd.read_csv('C:/jupyter-files/cakd7/second_projects/생성데이터/RFM/1. 원본_가중치 계산/Frequency_org_q1.csv', index_col=0)
f1
# Out:
#         Frequency_가구인테리어/잡화_고가  Frequency_가구인테리어/잡화_저가  \
# CUSTNO
# 1                          0.0                7.346542
# 2                          0.0               13.643577
# 3                          0.0               12.594071
# 4                          0.0                6.297036
# 6                          0.0                0.000000
# ...                        ...                     ...
# 19333                      0.0                0.000000
# 19334                      0.0                0.000000
# 19335                      0.0                2.099012
# 19336                      0.0                0.000000
# 19337                      0.0                0.000000
#
#         Frequency_가구인테리어/잡화_중가  Frequency_가전/레저취미/멀티샵_고가  \
# CUSTNO
# 1                     0.000000                  3.881286
# 2                     1.147152                  5.175048
# 3                     0.000000                  0.000000
# ...

# %%
f2 = pd.read_csv('C:/jupyter-files/cakd7/second_projects/생성데이터/RFM/1. 원본_가중치 계산/Frequency_org_q2.csv', index_col=0)
f2
# Out:
#         Frequency_가구인테리어/잡화_고가  Frequency_가구인테리어/잡화_저가  \
# CUSTNO
# 1                     0.000000                6.935270
# 2                     0.000000               17.833553
# 3                     0.000000               29.722588
# 4                     0.000000                3.963012
# 6                     0.909408                7.926023
# ...                        ...                     ...
# 19333                 0.000000                0.990753
# 19334                 0.000000                0.000000
# 19335                 0.000000                3.963012
# 19336                 0.000000                0.990753
# 19337                 0.000000                0.000000
#
#         Frequency_가구인테리어/잡화_중가  Frequency_가전/레저취미/멀티샵_고가  \
# CUSTNO
# 1                     5.131477                  5.637224
# 2                     1.710492                  4.026589
# 3                     0.000000                  0.000000
# ...

# %%
f3 = pd.read_csv('C:/jupyter-files/cakd7/second_projects/생성데이터/RFM/1. 원본_가중치 계산/Frequency_org_q3.csv', index_col=0)
f3
# Out:
#         Frequency_가구인테리어/잡화_고가  Frequency_가구인테리어/잡화_저가  \
# CUSTNO
# 1                     1.053957                4.077217
# 2                     0.000000                9.173738
# 3                     0.000000               28.540520
# 4                     0.000000                5.096521
# 6                     1.053957                2.038609
# ...                        ...                     ...
# 19333                 0.000000                2.038609
# 19334                 0.000000                3.057913
# 19335                 0.000000               14.270260
# 19336                 0.000000                2.038609
# 19337                 0.000000                4.077217
#
#         Frequency_가구인테리어/잡화_중가  Frequency_가전/레저취미/멀티샵_고가  \
# CUSTNO
# 1                     2.034350                  0.000000
# 2                     0.000000                  6.552826
# 3                     0.000000                  0.000000
# ...

# %%
f1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18866 entries, 1 to 19337
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Frequency_가구인테리어/잡화_고가    18866 non-null  float64
#  1   Frequency_가구인테리어/잡화_저가    18866 non-null  float64
#  2   Frequency_가구인테리어/잡화_중가    18866 non-null  float64
#  3   Frequency_가전/레저취미/멀티샵_고가  18866 non-null  float64
#  4   Frequency_가전/레저취미/멀티샵_저가  18866 non-null  float64
#  5   Frequency_가전/레저취미/멀티샵_중가  18866 non-null  float64
#  6   Frequency_교육문화/아동_고가      18866 non-null  float64
#  7   Frequency_교육문화/아동_저가      18866 non-null  float64
#  8   Frequency_교육문화/아동_중가      18866 non-null  float64
#  9   Frequency_식품/생활_고가        18866 non-null  float64
#  10  Frequency_식품/생활_저가        18866 non-null  float64
#  11  Frequency_식품/생활_중가        18866 non-null  float64
#  12  Frequency_의류/이미용_고가       18866 non-null  float64
# ...

# %% [markdown]
# # 추세선 넣을 빈 데이터 프레임

# %%
trendline = pd.DataFrame(index=f1.index, columns =f1.columns)
trendline
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# 6                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 19333                     NaN                    NaN                    NaN
# 19334                     NaN                    NaN                    NaN
# 19335                     NaN                    NaN                    NaN
# 19336                     NaN                    NaN                    NaN
# 19337                     NaN                    NaN                    NaN
#
# ...

# %% [markdown]
# # 실험

# %%
x = [1, 2, 3]
for i in x:
    print(str(i))
# Out:
# 1
# 2
# 3

# %%
y1 = f1.iloc[0,0]
y2 = f2.iloc[0,0]
y3 = f3.iloc[0,0]

print(y1, y2, y3)
# Out:
# 0.0 0.0 1.0539565706460603

# %%
import numpy as np
y = []
x = [1, 2, 3]
y1 = f1.iloc[0,8]
y2 = f2.iloc[0,8]
y3 = f3.iloc[0,8]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0]) # [
# Out:
# -0.5363256279460195

# %%
trendline.iloc[0,8] = fit_line[0]

# %%
trendline
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    0.526978              -1.634662               1.017175
# 2                         0.0              -2.234919              -0.573576
# 3                         0.0               7.973224                    0.0
# 4                         0.0              -0.600257              -0.573576
# 6                    0.526978               1.019304               0.508588
# ...                       ...                    ...                    ...
# 19333                     0.0               1.019304                    0.0
# 19334                     0.0               1.528956                    0.0
# 19335                     0.0               6.085624                    0.0
# 19336                     0.0               1.019304               1.525763
# 19337                     0.0               2.038609                    0.0
#
# ...

# %% [markdown]
# # 추세선 값 적용

# %%
import numpy as np
x = [1, 2, 3]
for i in range(len(f1.index)):
    for j in range(len(f1.columns)):
        y = []
        y1 = f1.iloc[i,j]
        y2 = f2.iloc[i,j]
        y3 = f3.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원
        linear = fit_line[0]
        trendline.iloc[i,j] = fit_line[0]
trendline
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    0.526978              -1.634662               1.017175
# 2                         0.0              -2.234919              -0.573576
# 3                         0.0               7.973224                    0.0
# 4                         0.0              -0.600257              -0.573576
# 6                    0.526978               1.019304               0.508588
# ...                       ...                    ...                    ...
# 19333                     0.0               1.019304                    0.0
# 19334                     0.0               1.528956                    0.0
# 19335                     0.0               6.085624                    0.0
# 19336                     0.0               1.019304               1.525763
# 19337                     0.0               2.038609                    0.0
#
# ...

# %%
trendline
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    0.526978              -1.634662               1.017175
# 2                         0.0              -2.234919              -0.573576
# 3                         0.0               7.973224                    0.0
# 4                         0.0              -0.600257              -0.573576
# 6                    0.526978               1.019304               0.508588
# ...                       ...                    ...                    ...
# 19333                     0.0               1.019304                    0.0
# 19334                     0.0               1.528956                    0.0
# 19335                     0.0               6.085624                    0.0
# 19336                     0.0               1.019304               1.525763
# 19337                     0.0               2.038609                    0.0
#
# ...

# %%
trendline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18866 entries, 1 to 19337
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Frequency_가구인테리어/잡화_고가    18866 non-null  object
#  1   Frequency_가구인테리어/잡화_저가    18866 non-null  object
#  2   Frequency_가구인테리어/잡화_중가    18866 non-null  object
#  3   Frequency_가전/레저취미/멀티샵_고가  18866 non-null  object
#  4   Frequency_가전/레저취미/멀티샵_저가  18866 non-null  object
#  5   Frequency_가전/레저취미/멀티샵_중가  18866 non-null  object
#  6   Frequency_교육문화/아동_고가      18866 non-null  object
#  7   Frequency_교육문화/아동_저가      18866 non-null  object
#  8   Frequency_교육문화/아동_중가      18866 non-null  object
#  9   Frequency_식품/생활_고가        18866 non-null  object
#  10  Frequency_식품/생활_저가        18866 non-null  object
#  11  Frequency_식품/생활_중가        18866 non-null  object
#  12  Frequency_의류/이미용_고가       18866 non-null  object
# ...

# %%
trendline.describe()
# Out:
#         Frequency_가구인테리어/잡화_고가  Frequency_가구인테리어/잡화_저가  \
# count                  18866.0                 18866.0
# unique                   492.0                  2066.0
# top                        0.0                     0.0
# freq                   12432.0                   781.0
#
#         Frequency_가구인테리어/잡화_중가  Frequency_가전/레저취미/멀티샵_고가  \
# count                  18866.0                   18866.0
# unique                   650.0                     592.0
# top                        0.0                       0.0
# freq                    6951.0                   13946.0
#
#         Frequency_가전/레저취미/멀티샵_저가  Frequency_가전/레저취미/멀티샵_중가  \
# count                    18866.0                   18866.0
# unique                     828.0                     987.0
# top                          0.0                       0.0
# freq                      7432.0                    5536.0
#
#         Frequency_교육문화/아동_고가  Frequency_교육문화/아동_저가  Frequency_교육문화/아동_중가  \
# ...

# %%
trendline.to_csv('F_추세선_123분기_1022.csv')

# %% [markdown]
# # 전체 데이터 불러오기

# %%
import pandas as pd

f1 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q1.csv', index_col=0)
f2 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q2.csv', index_col=0)
f3 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q3.csv', index_col=0)
f4 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q4.csv', index_col=0)
f5 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q5.csv', index_col=0)
f6 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q6.csv', index_col=0)
f7 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q7.csv', index_col=0)
f8 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q8.csv', index_col=0)
f8
# Out:
#         Frequency_가구인테리어/잡화_고가  Frequency_가구인테리어/잡화_저가  \
# CUSTNO
# 1                     0.000000                2.838823
# 2                     0.000000               14.194115
# 3                     0.000000                0.946274
# 4                     0.000000                6.623920
# 6                     0.909754                3.785097
# ...                        ...                     ...
# 19333                 0.000000                0.000000
# 19334                 0.000000                0.000000
# 19335                 0.000000                2.838823
# 19336                 0.909754                5.677646
# 19337                 0.000000                0.000000
#
#         Frequency_가구인테리어/잡화_중가  Frequency_가전/레저취미/멀티샵_고가  \
# CUSTNO
# 1                     1.024688                   0.93486
# 2                     0.000000                   0.93486
# 3                     0.000000                   0.00000
# ...

# %%
# 추체선 값 적용
import numpy as np
x = [1, 2, 3]

df_li = [f1, f2, f3, f4, f5, f6, f7, f8]

for q in range(5,6):
    # 추세선을 넣을 빈 데이터프레임
    trendline = pd.DataFrame(index = f1.index, columns = f1.columns)
    trendline

    for i in range(len(f1.index)):
        for j in range(len(f1.columns)):
            y = []
            y1 = df_li[q].iloc[i,j]
            y2 = df_li[q+1].iloc[i,j]
            y3 = df_li[q+2].iloc[i,j]
            y.extend([y1, y2, y3])
            fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원
            linear = fit_line[0]
#             fit_curve = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 2차원
#             curve = fit_curve[0]

            trendline.iloc[i,j] = linear
    display(trendline)
    trendline.to_csv(f'C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/3분기별추세선/2차_추세선q{q+1}_q{q+3}.csv')
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                   -0.454704               0.428659               0.084721
# 2                         0.0               0.657163                    0.0
# 3                         0.0              -0.022239                    0.0
# 4                         0.0              -0.651052              -0.427623
# 6                    0.000173              -0.088957               0.084721
# ...                       ...                    ...                    ...
# 19333                     0.0                    0.0                    0.0
# 19334                     0.0              -0.990753                    0.0
# 19335                     0.0              -1.552847              -0.427623
# 19336                0.000173               2.838823               0.681785
# 19337                     0.0                    0.0               0.512344
#
# ...

# %% [markdown]
# ### top1,2 확인

# %%
import numpy as np

x = [1, 2, 3]
y = [0 , 1]

for i in y:
    for j in y:
        for k in y:
            yy = []
            y1 = i
            y2 = j
            y3 = k
            
            yy.extend([y1,y2,y3])
            
            fit_line = np.polyfit(x, yy, 2)
            linear = fit_line[0]
            
            print(f'y = [{i}, {j}, {k}]')
            print(linear,'\n')

# %% [markdown]
# # 재시작

# %%
import pandas as pd

f1 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q1.csv', index_col=0)
f2 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q2.csv', index_col=0)
f3 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q3.csv', index_col=0)
f4 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q4.csv', index_col=0)
f5 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q5.csv', index_col=0)
f6 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q6.csv', index_col=0)
f7 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q7.csv', index_col=0)
f8 = pd.read_csv('C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/RFM/1. 원본_가중치 계산/1. 등급화 이전/Frequency_org_q8.csv', index_col=0)
f8
# Out:
#         Frequency_가구인테리어/잡화_고가  Frequency_가구인테리어/잡화_저가  \
# CUSTNO
# 1                     0.000000                2.838823
# 2                     0.000000               14.194115
# 3                     0.000000                0.946274
# 4                     0.000000                6.623920
# 6                     0.909754                3.785097
# ...                        ...                     ...
# 19333                 0.000000                0.000000
# 19334                 0.000000                0.000000
# 19335                 0.000000                2.838823
# 19336                 0.909754                5.677646
# 19337                 0.000000                0.000000
#
#         Frequency_가구인테리어/잡화_중가  Frequency_가전/레저취미/멀티샵_고가  \
# CUSTNO
# 1                     1.024688                   0.93486
# 2                     0.000000                   0.93486
# 3                     0.000000                   0.00000
# ...

# %%
# 추체선 값 적용
import numpy as np
x = [1, 2, 3, 4, 5, 6]

df_li = [f1, f2, f3, f4, f5, f6, f7, f8]

for q in range(3):
    # 추세선을 넣을 빈 데이터프레임
    trendline = pd.DataFrame(index = f1.index, columns = f1.columns)
    trendline

    for i in range(len(f1.index)):
        for j in range(len(f1.columns)):
            y = []
            y1 = df_li[q].iloc[i,j]
            y2 = df_li[q+1].iloc[i,j]
            y3 = df_li[q+2].iloc[i,j]
            y4 = df_li[q+3].iloc[i,j]
            y5 = df_li[q+4].iloc[i,j]
            y6 = df_li[q+5].iloc[i,j]
            y.extend([y1, y2, y3, y4, y5, y6])
            fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원
            linear = fit_line[0]
#             fit_curve = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 2차원
#             curve = fit_curve[0]

            trendline.iloc[i,j] = linear
    display(trendline)
    trendline.to_csv(f'C:/cakd7/cakd7_class/github_구매감소예측프로젝트/second_projects/생성데이터/추세선/6분기별추세선/f_추세선q{q+1}_q{q+6}.csv')
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    0.200361              -0.802449               0.400335
# 2                    0.428228              -0.612875               -0.01551
# 3                         0.0              -4.237146                    0.0
# 4                         0.0               0.179502              -0.261621
# 6                    0.021853               0.566374              -0.053498
# ...                       ...                    ...                    ...
# 19333                     0.0              -0.116131                    0.0
# 19334                     0.0               0.537837                    0.0
# 19335                     0.0               0.179968               0.122178
# 19336                0.155908              -0.089095               0.305538
# 19337                     0.0              -0.089456                    0.0
#
# ...
