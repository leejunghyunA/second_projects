# %%
f1 = pd.read_csv('C:/jupyter-files/cakd7/second_projects/생성데이터/RFM/1. 원본_가중치 계산/Frequency_org_q1.csv', index_col=0)
f2 = pd.read_csv('C:/jupyter-files/cakd7/second_projects/생성데이터/RFM/1. 원본_가중치 계산/Frequency_org_q2.csv', index_col=0)
f3 = pd.read_csv('C:/jupyter-files/cakd7/second_projects/생성데이터/RFM/1. 원본_가중치 계산/Frequency_org_q3.csv', index_col=0)
f4 = pd.read_csv('C:/jupyter-files/cakd7/second_projects/생성데이터/RFM/1. 원본_가중치 계산/Frequency_org_q4.csv', index_col=0)
f5 = pd.read_csv('C:/jupyter-files/cakd7/second_projects/생성데이터/RFM/1. 원본_가중치 계산/Frequency_org_q5.csv', index_col=0)
f6 = pd.read_csv('C:/jupyter-files/cakd7/second_projects/생성데이터/RFM/1. 원본_가중치 계산/Frequency_org_q6.csv', index_col=0)
f7 = pd.read_csv('C:/jupyter-files/cakd7/second_projects/생성데이터/RFM/1. 원본_가중치 계산/Frequency_org_q7.csv', index_col=0)

# %% [markdown]
# # 일차함수

# %% [markdown]
# ## 123분기

# %% [markdown]
# ### 추세선 넣을 빈 데이터 프레임

# %%
trendline = pd.DataFrame(index=f1.index, columns =f1.columns)
trendline
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# 6                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 19333                     NaN                    NaN                    NaN
# 19334                     NaN                    NaN                    NaN
# 19335                     NaN                    NaN                    NaN
# 19336                     NaN                    NaN                    NaN
# 19337                     NaN                    NaN                    NaN
#
# ...

# %% [markdown]
# ### 실험

# %%
x = [1, 2, 3]
for i in x:
    print(str(i))
# Out:
# 1
# 2
# 3

# %%
y1 = f1.iloc[0,0]
y2 = f2.iloc[0,0]
y3 = f3.iloc[0,0]

print(y1, y2, y3)
# Out:
# 0.0 0.0 1.0539565706460603

# %%
import numpy as np
y = []
x = [1, 2, 3]
y1 = f1.iloc[0,8]
y2 = f2.iloc[0,8]
y3 = f3.iloc[0,8]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0]) # [
# Out:
# -0.5363256279460195

# %%
trendline.iloc[0,8] = fit_line[0]

# %%
trendline
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    0.526978              -1.634662               1.017175
# 2                         0.0              -2.234919              -0.573576
# 3                         0.0               7.973224                    0.0
# 4                         0.0              -0.600257              -0.573576
# 6                    0.526978               1.019304               0.508588
# ...                       ...                    ...                    ...
# 19333                     0.0               1.019304                    0.0
# 19334                     0.0               1.528956                    0.0
# 19335                     0.0               6.085624                    0.0
# 19336                     0.0               1.019304               1.525763
# 19337                     0.0               2.038609                    0.0
#
# ...

# %% [markdown]
# ### 추세선 값 적용

# %%
import numpy as np
x = [1, 2, 3]
for i in range(len(f1.index)):
    for j in range(len(f1.columns)):
        y = []
        y1 = f1.iloc[i,j]
        y2 = f2.iloc[i,j]
        y3 = f3.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원
        linear = fit_line[0]
        trendline.iloc[i,j] = fit_line[0]
trendline
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    0.526978              -1.634662               1.017175
# 2                         0.0              -2.234919              -0.573576
# 3                         0.0               7.973224                    0.0
# 4                         0.0              -0.600257              -0.573576
# 6                    0.526978               1.019304               0.508588
# ...                       ...                    ...                    ...
# 19333                     0.0               1.019304                    0.0
# 19334                     0.0               1.528956                    0.0
# 19335                     0.0               6.085624                    0.0
# 19336                     0.0               1.019304               1.525763
# 19337                     0.0               2.038609                    0.0
#
# ...

# %%
trendline
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    0.526978              -1.634662               1.017175
# 2                         0.0              -2.234919              -0.573576
# 3                         0.0               7.973224                    0.0
# 4                         0.0              -0.600257              -0.573576
# 6                    0.526978               1.019304               0.508588
# ...                       ...                    ...                    ...
# 19333                     0.0               1.019304                    0.0
# 19334                     0.0               1.528956                    0.0
# 19335                     0.0               6.085624                    0.0
# 19336                     0.0               1.019304               1.525763
# 19337                     0.0               2.038609                    0.0
#
# ...

# %%
trendline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18866 entries, 1 to 19337
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Frequency_가구인테리어/잡화_고가    18866 non-null  object
#  1   Frequency_가구인테리어/잡화_저가    18866 non-null  object
#  2   Frequency_가구인테리어/잡화_중가    18866 non-null  object
#  3   Frequency_가전/레저취미/멀티샵_고가  18866 non-null  object
#  4   Frequency_가전/레저취미/멀티샵_저가  18866 non-null  object
#  5   Frequency_가전/레저취미/멀티샵_중가  18866 non-null  object
#  6   Frequency_교육문화/아동_고가      18866 non-null  object
#  7   Frequency_교육문화/아동_저가      18866 non-null  object
#  8   Frequency_교육문화/아동_중가      18866 non-null  object
#  9   Frequency_식품/생활_고가        18866 non-null  object
#  10  Frequency_식품/생활_저가        18866 non-null  object
#  11  Frequency_식품/생활_중가        18866 non-null  object
#  12  Frequency_의류/이미용_고가       18866 non-null  object
# ...

# %%
trendline.describe()
# Out:
#         Frequency_가구인테리어/잡화_고가  Frequency_가구인테리어/잡화_저가  \
# count                  18866.0                 18866.0
# unique                   492.0                  2066.0
# top                        0.0                     0.0
# freq                   12432.0                   781.0
#
#         Frequency_가구인테리어/잡화_중가  Frequency_가전/레저취미/멀티샵_고가  \
# count                  18866.0                   18866.0
# unique                   650.0                     592.0
# top                        0.0                       0.0
# freq                    6951.0                   13946.0
#
#         Frequency_가전/레저취미/멀티샵_저가  Frequency_가전/레저취미/멀티샵_중가  \
# count                    18866.0                   18866.0
# unique                     828.0                     987.0
# top                          0.0                       0.0
# freq                      7432.0                    5536.0
#
#         Frequency_교육문화/아동_고가  Frequency_교육문화/아동_저가  Frequency_교육문화/아동_중가  \
# ...

# %%
trendline.to_csv('F_추세선_123분기_1022.csv')

# %% [markdown]
# ## 234 분기

# %%
trendline2 = pd.DataFrame(index=f2.index, columns =f2.columns)
trendline2
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# 6                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 19333                     NaN                    NaN                    NaN
# 19334                     NaN                    NaN                    NaN
# 19335                     NaN                    NaN                    NaN
# 19336                     NaN                    NaN                    NaN
# 19337                     NaN                    NaN                    NaN
#
# ...

# %%
import numpy as np
x = [2, 3, 4]
for i in range(len(f2.index)):
    for j in range(len(f2.columns)):
        y = []
        y1 = f2.iloc[i,j]
        y2 = f3.iloc[i,j]
        y3 = f4.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원
        linear = fit_line[0]
        trendline2.iloc[i,j] = linear
trendline2
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                         0.0              -1.101949              -1.028707
# 2                    0.454877              -3.712268              -0.855246
# 3                         0.0              -5.871688                    0.0
# 4                         0.0               0.857317              -1.282869
# 6                   -0.454704              -2.070463              -0.855246
# ...                       ...                    ...                    ...
# 19333                     0.0              -0.022239                    0.0
# 19334                     0.0               2.838823                    0.0
# 19335                     0.0              -0.088957                    0.0
# 19336                0.454877               0.450898              -0.855246
# 19337                     0.0               0.473137                    0.0
#
# ...

# %% [markdown]
# ### 확인

# %%
import numpy as np
y = []
x = [2, 3, 4]
y1 = f2.iloc[0,8]
y2 = f3.iloc[0,8]
y3 = f4.iloc[0,8]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0])
# Out:
# -0.47504546806368986

# %% [markdown]
# ### 저장

# %%
trendline2.to_csv('F_추세선_234분기_1023.csv')

# %% [markdown]
# ## 345분기

# %%
trendline3 = pd.DataFrame(index=f2.index, columns =f2.columns)
trendline3
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# 6                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 19333                     NaN                    NaN                    NaN
# 19334                     NaN                    NaN                    NaN
# 19335                     NaN                    NaN                    NaN
# 19336                     NaN                    NaN                    NaN
# 19337                     NaN                    NaN                    NaN
#
# ...

# %%
import numpy as np
x = [3, 4, 5]
for i in range(len(f2.index)):
    for j in range(len(f2.columns)):
        y = []
        y1 = f3.iloc[i,j]
        y2 = f4.iloc[i,j]
        y3 = f5.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원
        linear = fit_line[0]
        trendline3.iloc[i,j] = linear
trendline3
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    0.059615               1.109909               2.997858
# 2                    2.346372               1.185413               1.720729
# 3                         0.0             -12.696001                    0.0
# 4                         0.0              -0.974002                    0.0
# 6                   -0.526978               2.653967              -0.508588
# ...                       ...                    ...                    ...
# 19333                     0.0              -1.019304                    0.0
# 19334                     0.0               -0.47945                    0.0
# 19335                     0.0              -5.560871                    0.0
# 19336                     0.0              -1.019304               0.194966
# 19337                     0.0              -2.038609                    0.0
#
# ...

# %%
import numpy as np
y = []
x = [3, 4, 5]
y1 = f3.iloc[0,9]
y2 = f4.iloc[0,9]
y3 = f5.iloc[0,9]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0])
# Out:
# 5.742409003705532

# %%
trendline3.to_csv('F_추세선_345분기_1023.csv')

# %% [markdown]
# ## 456분기

# %%
trendline4 = pd.DataFrame(index=f2.index, columns =f2.columns)
trendline4
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# 6                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 19333                     NaN                    NaN                    NaN
# 19334                     NaN                    NaN                    NaN
# 19335                     NaN                    NaN                    NaN
# 19336                     NaN                    NaN                    NaN
# 19337                     NaN                    NaN                    NaN
#
# ...

# %%
import numpy as np
x = [4,5,6]
for i in range(len(f2.index)):
    for j in range(len(f2.columns)):
        y = []
        y1 = f4.iloc[i,j]
        y2 = f5.iloc[i,j]
        y3 = f6.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원
        linear = fit_line[0]
        trendline4.iloc[i,j] = linear
trendline4
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    0.454704              -1.374933              -1.109408
# 2                   -0.454877               1.235385                    0.0
# 3                         0.0               -8.49423                    0.0
# 4                         0.0               1.124189               0.427623
# 6                    0.454704               0.088957               0.427623
# ...                       ...                    ...                    ...
# 19333                     0.0              -0.473137                    0.0
# 19334                     0.0               -1.84807                    0.0
# 19335                     0.0                1.07971               0.427623
# 19336               -0.000173              -0.946274               0.855246
# 19337                     0.0              -0.473137                    0.0
#
# ...

# %%
import numpy as np
y = []
x = [4,5,6]
y1 = f4.iloc[0,9]
y2 = f5.iloc[0,9]
y3 = f6.iloc[0,9]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0])
# Out:
# -0.9418483596640638

# %%
trendline4.to_csv('F_추세선_456분기_1023.csv')

# %% [markdown]
# ## 567분기

# %%
trendline5 = pd.DataFrame(index=f2.index, columns =f2.columns)
trendline5
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# 6                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 19333                     NaN                    NaN                    NaN
# 19334                     NaN                    NaN                    NaN
# 19335                     NaN                    NaN                    NaN
# 19336                     NaN                    NaN                    NaN
# 19337                     NaN                    NaN                    NaN
#
# ...

# %%
import numpy as np
x = [5,6,7]
for i in range(len(f2.index)):
    for j in range(len(f2.columns)):
        y = []
        y1 = f5.iloc[i,j]
        y2 = f6.iloc[i,j]
        y3 = f7.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원
        linear = fit_line[0]
        trendline5.iloc[i,j] = linear
trendline5
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                   -0.586593              -3.148518              -0.963508
# 2                   -2.346372               1.872499              -1.720729
# 3                         0.0              -0.554955                    0.0
# 4                         0.0               1.483654               0.508588
# 6                    1.053957              -2.144314               1.017175
# ...                       ...                    ...                    ...
# 19333                     0.0                    0.0                    0.0
# 19334                     0.0              -1.049506                    0.0
# 19335                     0.0              -0.554955                    0.0
# 19336                1.053957               1.019304               0.313622
# 19337                     0.0                    0.0                    0.0
#
# ...

# %%
import numpy as np
y = []
x = [5,6,7]
y1 = f5.iloc[0,9]
y2 = f6.iloc[0,9]
y3 = f7.iloc[0,9]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 1) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0])
# Out:
# -5.742409003705523

# %%
trendline5.to_csv('F_추세선_567분기_1023.csv')

# %% [markdown]
# # 2차 함수

# %%
trendline_qu = pd.DataFrame(index=f2.index, columns =f2.columns)
trendline_qu2 = pd.DataFrame(index=f2.index, columns =f2.columns)
trendline_qu3 = pd.DataFrame(index=f2.index, columns =f2.columns)
trendline_qu4 = pd.DataFrame(index=f2.index, columns =f2.columns)
trendline_qu5 = pd.DataFrame(index=f2.index, columns =f2.columns)

# %% [markdown]
# ## 1,2,3분기

# %%
import numpy as np
x = [1,2,3]
for i in range(len(f2.index)):
    for j in range(len(f2.columns)):
        y = []
        y1 = f1.iloc[i,j]
        y2 = f2.iloc[i,j]
        y3 = f3.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 1차원
        quad = fit_line[0]
        trendline_qu.iloc[i,j] = quad
trendline_qu
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    0.526978              -1.223391              -4.114302
# 2                         0.0              -6.424895              -1.136916
# 3                         0.0              -9.155292                    0.0
# 4                         0.0               1.733767              -1.992162
# 6                    -0.38243              -6.906719              -1.201905
# ...                       ...                    ...                    ...
# 19333                     0.0               0.028551                    0.0
# 19334                     0.0               1.528956                    0.0
# 19335                     0.0               4.221624                    0.0
# 19336                     0.0               0.028551               -0.18473
# 19337                     0.0               2.038609                    0.0
#
# ...

# %%
import numpy as np
y = []
x = [1,2,3]
y1 = f1.iloc[0,1]
y2 = f2.iloc[0,1]
y3 = f3.iloc[0,1]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0])
# Out:
# -1.2233911145178438

# %%
trendline_qu.to_csv('F_추세선_123분기_2차_1023.csv')

# %% [markdown]
# ## 234분기

# %%
import numpy as np
x = [2,3,4]
for i in range(len(f2.index)):
    for j in range(len(f2.columns)):
        y = []
        y1 = f2.iloc[i,j]
        y2 = f3.iloc[i,j]
        y3 = f4.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 1차원
        quad = fit_line[0]
        trendline_qu2.iloc[i,j] = quad
trendline_qu2
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                   -1.053957               1.756104                2.06842
# 2                    0.454877               4.947547               0.855246
# 3                         0.0               -4.68962                    0.0
# 4                         0.0              -0.276193               1.282869
# 6                   -0.599252               3.816952              -0.161929
# ...                       ...                    ...                    ...
# 19333                     0.0              -1.070095                    0.0
# 19334                     0.0               -0.21909                    0.0
# 19335                     0.0             -10.396205                    0.0
# 19336                0.454877              -0.596958              -2.196279
# 19337                     0.0               -3.60408                    0.0
#
# ...

# %%
import numpy as np
y = []
x = [2,3,4]
y1 = f2.iloc[0,1]
y2 = f3.iloc[0,1]
y3 = f4.iloc[0,1]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0])
# Out:
# 1.756103930697904

# %%
trendline_qu2.to_csv('F_추세선_234분기_2차_1023.csv')

# %% [markdown]
# ## 345분기

# %%
import numpy as np
x = [3,4,5]
for i in range(len(f2.index)):
    for j in range(len(f2.columns)):
        y = []
        y1 = f3.iloc[i,j]
        y2 = f4.iloc[i,j]
        y3 = f5.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 1차원
        quad = fit_line[0]
        trendline_qu3.iloc[i,j] = quad
trendline_qu3
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                    1.113571               0.455755               1.958146
# 2                    1.436618              -0.049866               1.720729
# 3                         0.0              -2.134693                    0.0
# 4                         0.0              -1.555126                    0.0
# 6                    0.526978               0.907478               0.508588
# ...                       ...                    ...                    ...
# 19333                     0.0                0.07303                    0.0
# 19334                     0.0              -3.099184                    0.0
# 19335                     0.0               4.924292                    0.0
# 19336               -0.909754              -0.873244               3.246491
# 19337                     0.0               1.092334                    0.0
#
# ...

# %%
import numpy as np
y = []
x = [3,4,5]
y1 = f3.iloc[0,1]
y2 = f4.iloc[0,1]
y3 = f5.iloc[0,1]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0])
# Out:
# 0.4557547438604732

# %%
trendline_qu3.to_csv('F_추세선_345분기_2차_1023.csv')

# %% [markdown]
# ## 4,5,6분기

# %%
import numpy as np
x = [4,5,6]
for i in range(len(f2.index)):
    for j in range(len(f2.columns)):
        y = []
        y1 = f4.iloc[i,j]
        y2 = f5.iloc[i,j]
        y3 = f6.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 1차원
        quad = fit_line[0]
        trendline_qu4.iloc[i,j] = quad
trendline_qu4
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                   -0.718482              -2.940597              -6.065412
# 2                   -4.237866               0.099837              -3.441457
# 3                         0.0               6.336465                    0.0
# 4                         0.0               3.653317               0.427623
# 6                    0.454704              -3.472487               0.427623
# ...                       ...                    ...                    ...
# 19333                     0.0               0.473137                    0.0
# 19334                     0.0               1.730564                    0.0
# 19335                     0.0                1.71629               0.427623
# 19336                0.909581               0.946274              -2.586211
# 19337                     0.0               0.473137                    0.0
#
# ...

# %%
import numpy as np
y = []
x = [4,5,6]
y1 = f4.iloc[0,1]
y2 = f5.iloc[0,1]
y3 = f6.iloc[0,1]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0])
# Out:
# -2.9405968958786453

# %%
trendline_qu4.to_csv('F_추세선_456분기_2차_1023.csv')

# %% [markdown]
# # 567분기

# %%
import numpy as np
x = [5,6,7]
for i in range(len(f2.index)):
    for j in range(len(f2.columns)):
        y = []
        y1 = f5.iloc[i,j]
        y2 = f6.iloc[i,j]
        y3 = f7.iloc[i,j]
        y.extend([y1, y2, y3])
        fit_line = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 1차원
        quad = fit_line[0]
        trendline_qu5.iloc[i,j] = quad
trendline_qu5
# Out:
#        Frequency_가구인테리어/잡화_고가 Frequency_가구인테리어/잡화_저가 Frequency_가구인테리어/잡화_중가  \
# CUSTNO
# 1                   -0.322815               1.167012               6.211312
# 2                    2.346372               0.537277               1.720729
# 3                         0.0                1.60281                    0.0
# 4                         0.0              -3.293852              -0.346659
# 6                    0.144548               1.239216               0.161929
# ...                       ...                    ...                    ...
# 19333                     0.0                    0.0                    0.0
# 19334                     0.0                 -0.932                    0.0
# 19335                     0.0              -3.350954              -0.855246
# 19336                0.144548               1.019304               2.044586
# 19337                     0.0                    0.0                    0.0
#
# ...

# %%
import numpy as np
y = []
x = [5,6,7]
y1 = f5.iloc[0,1]
y2 = f6.iloc[0,1]
y3 = f7.iloc[0,1]
y.extend([y1, y2, y3])
fit_line = np.polyfit(x, y, 2) # input 의미 : x축 데이터, y축 데이터, 1차원

print(fit_line[0])
# Out:
# 1.1670119715379317

# %%
trendline_qu5.to_csv('F_추세선_567분기_2차_1023.csv')
